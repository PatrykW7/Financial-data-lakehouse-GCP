# %%
# DANE Z API POBIERANY PRZEZ PYTHON BEZ SPARK'a

# %%
import pandas as pd
import requests
import datetime
from zoneinfo import ZoneInfo

# %%
# I IMPORT Z API

# %%
### 1. SEC

# %%
headers = {'User-Agent': "patryczkatadeusz7@gmail.com"}

# %%
companyTickers = requests.get("https://www.sec.gov/files/company_tickers_exchange.json", headers = headers)
companyTickers
# Out:
# <Response [200]>

# %%
#companyTickers.json()

# %%
companyTickers.json()["data"]
df = pd.DataFrame(companyTickers.json()["data"], columns = ['cik', 'name', 'ticker', 'exchange'])
df["cik"] = df["cik"].astype(str).str.zfill(10)
df.head()
# Out:
#           cik            name ticker exchange
# 0  0000320193      Apple Inc.   AAPL   Nasdaq
# 1  0001045810     NVIDIA CORP   NVDA   Nasdaq
# 2  0001652044   Alphabet Inc.  GOOGL   Nasdaq
# 3  0000789019  MICROSOFT CORP   MSFT   Nasdaq
# 4  0001018724  AMAZON COM INC   AMZN   Nasdaq

# %%
cik_list = df.head(50)["cik"].to_list()
#cik_list

# %%
df.groupby("name")["ticker"].nunique().sort_values(ascending = False)
# Out:
# name
# BANK OF MONTREAL /CAN/             27
# FEDERAL HOME LOAN MORTGAGE CORP    25
# UBS AG                             19
# BANK OF AMERICA CORP /DE/          17
# Public Storage                     17
#                                    ..
# Frequency Holdings, Inc             1
# Frequency Exchange Corp.            1
# FreightCar America, Inc.            1
# Freight Technologies, Inc.          1
# Fujikura Ltd/ADR                    1
# Name: ticker, Length: 8000, dtype: int64

# %%
#### 2. SEC - dane spółki

# %%
cik = "0001045810"

# %%
# METADATA DLA OKRESLONEGO CIK
fillingMetadata = requests.get(f'https://data.sec.gov/submissions/CIK{cik}.json', headers = headers)

# %%
allForms = pd.DataFrame.from_dict(fillingMetadata.json()["filings"]["recent"])
allForms.head()
# Out:
#         accessionNumber  filingDate  reportDate        acceptanceDateTime act  \
# 0  0001045810-26-000062  2026-07-20              2026-07-20T21:00:07.000Z
# 1  0001310264-26-000002  2026-07-15  2026-07-13  2026-07-15T21:03:12.000Z
# 2  0001197647-26-000005  2026-07-06  2026-07-01  2026-07-06T21:01:46.000Z
# 3  0001045810-26-000060  2026-07-02  2026-06-28  2026-07-02T13:23:16.000Z  34
# 4  0001045810-26-000056  2026-06-30  2026-06-24  2026-06-30T20:27:26.000Z  34
#
#            form fileNumber filmNumber items     core_type    size  isXBRL  \
# 0  SCHEDULE 13G                              SCHEDULE 13G    8766       0
# 1             3                                         3   11953       0
# 2             4                                         4    6863       0
# 3           8-K  000-23985  261148237  5.02          XBRL  138094       1
# 4           8-K  000-23985  261140846  5.07          XBRL  178639       1
#
#    isInlineXBRL  isXBRLNumeric                      primaryDocument  \
# 0             0            0.0  xslSCHEDULE_13G_X01/primary_doc.xml
# 1             0            0.0   xslF345X06/wk-form3_1784149389.xml
# 2             0            0.0   xslF345X06/wk-form4_1783371701.xml
# 3             1            0.0                    nvda-20260628.htm
# 4             1            0.0                    nvda-20260624.htm
#
#   primaryDocDescription
# 0
# 1                FORM 3
# 2                FORM 4
# 3                   8-K
# 4                   8-K

# %%
### 3. XBRL

# %%
#companyFacts = requests.get(f"https://data.sec.gov/api/xbrl/companyfacts/CIK{cik}.json", headers = headers)

# %%
#companyFacts.json()

# %%
### 4. Alpha Vantage API

# %%
TICKER = "NVDA"
TICKER_2 = "AAPL"
API_KEY = "5XGN60X31Y15LW6T"

# %%
alpha_vantage = requests.get(f"https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={TICKER}&outputsize=compact&apikey={API_KEY}")
#alpha_vantage.json()

# %%
                                                            # II ZAPIS do warstwy Bronze

# %%
    ### 2.1. SEC metadata

# %%
from google.cloud import storage
import json

# %%
# !date
# Out:
# Thu Jul 30 18:31:59 UTC 2026

# %%
datetime.datetime.now().astimezone()
# Out:
# datetime.datetime(2026, 7, 30, 18, 31, 59, 668654, tzinfo=datetime.timezone(datetime.timedelta(0), 'UTC'))

# %%
now = str(datetime.datetime.now(ZoneInfo("Europe/Warsaw")))
now
# Out:
# '2026-07-30 20:31:59.703069+02:00'

# %%
#companyTickers.json()

# %%
#json.dumps(companyTickers.json())

# %%
storage_client = storage.Client()
bucket = storage_client.get_bucket("project-dev-storage")

# %%
blob = bucket.blob(f"CIK/sec_metadata{str(datetime.datetime.now(ZoneInfo("Europe/Warsaw")))}")
blob.upload_from_string(json.dumps(companyTickers.json()), content_type = "json")

# %%
    # 2.2. SEC dane spółki

# %%
#fillingMetadata.json()

# %%
cik2 = "0000320193"

# %%
fillingMetadata2 = requests.get(f'https://data.sec.gov/submissions/CIK{cik2}.json', headers = headers)

# %%
# KONWERSJA KILKU CIK do wspolnego pliku json
# tutaj nalezy zrobic for loop gdzie bedzie z listy cik_list brac dane dla konkretnych spolek i laczyc je w spolny plik json i ladowac do bronze
wyn = [fillingMetadata.json(), fillingMetadata2.json()]
a = json.dumps(wyn)

# ODWRÓCENIE WCZESNIEJSZEJ OPERACJI
a_list = json.loads(a)

#a_list[1]

# %%
# Potem sie z tego robi DF w taki sposob, tutaj tez trzeba bedzie napisac for loop gdzie bedzie przechodzic po kazdym elemencie z listy a_list i 
# dodawac wiersze do DF dla kolejnych cik
allForms = pd.DataFrame.from_dict(fillingMetadata.json()["filings"]["recent"])
allForms.head()
# Out:
#         accessionNumber  filingDate  reportDate        acceptanceDateTime act  \
# 0  0001045810-26-000062  2026-07-20              2026-07-20T21:00:07.000Z
# 1  0001310264-26-000002  2026-07-15  2026-07-13  2026-07-15T21:03:12.000Z
# 2  0001197647-26-000005  2026-07-06  2026-07-01  2026-07-06T21:01:46.000Z
# 3  0001045810-26-000060  2026-07-02  2026-06-28  2026-07-02T13:23:16.000Z  34
# 4  0001045810-26-000056  2026-06-30  2026-06-24  2026-06-30T20:27:26.000Z  34
#
#            form fileNumber filmNumber items     core_type    size  isXBRL  \
# 0  SCHEDULE 13G                              SCHEDULE 13G    8766       0
# 1             3                                         3   11953       0
# 2             4                                         4    6863       0
# 3           8-K  000-23985  261148237  5.02          XBRL  138094       1
# 4           8-K  000-23985  261140846  5.07          XBRL  178639       1
#
#    isInlineXBRL  isXBRLNumeric                      primaryDocument  \
# 0             0            0.0  xslSCHEDULE_13G_X01/primary_doc.xml
# 1             0            0.0   xslF345X06/wk-form3_1784149389.xml
# 2             0            0.0   xslF345X06/wk-form4_1783371701.xml
# 3             1            0.0                    nvda-20260628.htm
# 4             1            0.0                    nvda-20260624.htm
#
#   primaryDocDescription
# 0
# 1                FORM 3
# 2                FORM 4
# 3                   8-K
# 4                   8-K

# %%
# ZAPIS DO BRONZE
blob = bucket.blob(f"company_forms/sec_metadata{str(datetime.datetime.now(ZoneInfo("Europe/Warsaw")))}")
blob.upload_from_string(json.dumps(wyn), content_type = "json")

# %%
    # 2.3 XBRL dane

# %%
companyFacts = requests.get(f"https://data.sec.gov/api/xbrl/companyfacts/CIK{cik}.json", headers = headers)
companyFacts2 = requests.get(f"https://data.sec.gov/api/xbrl/companyfacts/CIK{cik2}.json", headers = headers)

# %%
wyn_xbrl = [companyFacts.json(),
            companyFacts2.json()
]

a = json.dumps(wyn_xbrl)

# %%
# ZAPIS XBRL do BRONZE
blob = bucket.blob(f"company_values/{str(datetime.datetime.now(ZoneInfo("Europe/Warsaw")))}")
blob.upload_from_string(json.dumps(wyn_xbrl), content_type = "application/json")

# %%
    ### 2.4 ALPHA VANTAGE

# %%
alpha_vantage_1 = requests.get(f"https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={TICKER}&outputsize=compact&apikey={API_KEY}")
alpha_vantage_2 = requests.get(f"https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={TICKER_2}&outputsize=compact&apikey={API_KEY}")
#alpha_vantage.json()

# %%
alpha_vantage_2.json()
# Out:
# {'Information': 'Thank you for using Alpha Vantage! Please consider spreading out your free API requests more sparingly (1 request per second). You may subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to lift the free key rate limit (25 requests per day), raise the per-second burst limit, and instantly unlock all premium endpoints'}

# %%
wyn_alpha_vantage = [alpha_vantage_1.json(), alpha_vantage_2.json()]

a = json.dumps(wyn_alpha_vantage)
#

# %%
#a

# %%
# ZAPIS ALPHA VANTAGE DO BRONZE

# %%
blob = bucket.blob(f"alpha_vantage/{str(datetime.datetime.now(ZoneInfo("Europe/Warsaw")))}")
blob.upload_from_string(json.dumps(wyn_alpha_vantage), content_type = "application/json")
